# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
from tensorflow import keras
import numpy as np

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
x_train[:20]
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[110, 104,  97],
#          [142, 135, 118],
#          [151, 146, 120],
#          ...,
#          [ 39,  39,  39],
#          [ 40,  40,  40],
#          [ 38,  38,  38]],
#
#         [[109, 103,  95],
#          [141, 133, 115],
#          [152, 147, 119],
#          ...,
#          [ 36,  36,  37],
#          [ 40,  40,  40],
#          [ 36,  36,  36]],
#
#         [[105,  98,  90],
#          [142, 133, 114],
#          [151, 145, 117],
#          ...,
#          [ 39,  39,  41],
#          [ 44,  44,  45],
#          [ 39,  39,  40]],
#
#         ...,
#
#         [[ 62,  59,  60],
#          [ 39,  38,  49],
#          [ 60,  64,  81],
#          ...,
#          [ 42,  44,  56],
#          [ 46,  44,  55],
#          [ 47,  44,  55]],
#
#         [[ 62,  57,  56],
#          [ 52,  51,  61],
#          [ 58,  61,  78],
#          ...,
#          [ 43,  46,  58],
#          [ 47,  45,  58],
#          [ 49,  46,  60]],
#
#         [[ 55,  51,  50],
#          [ 60,  60,  71],
#          [ 56,  60,  78],
#          ...,
#          [ 45,  48,  60],
#          [ 47,  46,  60],
#          [ 51,  48,  62]]],
#
#
#        [[[197, 187, 188],
#          [198, 188, 189],
#          [201, 191, 192],
#          ...,
#          [217, 201, 204],
#          [217, 201, 204],
#          [217, 201, 204]],
#
#         [[193, 183, 184],
#          [195, 185, 186],
#          [198, 188, 189],
#          ...,
#          [216, 200, 203],
#          [215, 200, 202],
#          [214, 198, 201]],
#
#         [[192, 182, 183],
#          [194, 184, 185],
#          [197, 187, 188],
#          ...,
#          [217, 201, 204],
#          [216, 200, 203],
#          [215, 199, 202]],
#
#         ...,
#
#         [[156, 146, 147],
#          [156, 146, 147],
#          [156, 146, 147],
#          ...,
#          [ 98,  79,  65],
#          [117,  96,  82],
#          [128, 105,  89]],
#
#         [[158, 148, 149],
#          [159, 149, 150],
#          [154, 144, 145],
#          ...,
#          [131, 110,  96],
#          [117,  99,  86],
#          [ 91,  75,  64]],
#
#         [[152, 142, 143],
#          [151, 141, 142],
#          [145, 135, 136],
#          ...,
#          [ 91,  72,  61],
#          [ 90,  73,  63],
#          [ 79,  65,  57]]],
#
#
#        [[[ 23,  27,  22],
#          [ 47,  49,  41],
#          [ 52,  46,  30],
#          ...,
#          [131, 130, 117],
#          [182, 180, 174],
#          [215, 212, 230]],
#
#         [[ 32,  31,  24],
#          [ 51,  49,  38],
#          [ 56,  49,  34],
#          ...,
#          [149, 148, 133],
#          [204, 206, 197],
#          [209, 217, 232]],
#
#         [[ 41,  37,  25],
#          [ 59,  57,  47],
#          [ 60,  59,  51],
#          ...,
#          [138, 138, 125],
#          [196, 200, 194],
#          [203, 217, 233]],
#
#         ...,
#
#         [[167, 167, 168],
#          [177, 177, 177],
#          [182, 182, 182],
#          ...,
#          [199, 192, 192],
#          [176, 171, 171],
#          [145, 140, 140]],
#
#         [[166, 166, 166],
#          [165, 165, 165],
#          [165, 165, 165],
#          ...,
#          [183, 181, 181],
#          [183, 182, 182],
#          [189, 187, 188]],
#
#         [[175, 175, 175],
#          [173, 173, 173],
#          [173, 173, 173],
#          ...,
#          [190, 187, 184],
#          [188, 186, 183],
#          [192, 189, 186]]]], dtype=uint8)

# %%
x_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
x_test
# Out:
# array([[[[158, 112,  49],
#          [159, 111,  47],
#          [165, 116,  51],
#          ...,
#          [137,  95,  36],
#          [126,  91,  36],
#          [116,  85,  33]],
#
#         [[152, 112,  51],
#          [151, 110,  40],
#          [159, 114,  45],
#          ...,
#          [136,  95,  31],
#          [125,  91,  32],
#          [119,  88,  34]],
#
#         [[151, 110,  47],
#          [151, 109,  33],
#          [158, 111,  36],
#          ...,
#          [139,  98,  34],
#          [130,  95,  34],
#          [120,  89,  33]],
#
#         ...,
#
#         [[ 68, 124, 177],
#          [ 42, 100, 148],
#          [ 31,  88, 137],
#          ...,
#          [ 38,  97, 146],
#          [ 13,  64, 108],
#          [ 40,  85, 127]],
#
#         [[ 61, 116, 168],
#          [ 49, 102, 148],
#          [ 35,  85, 132],
#          ...,
#          [ 26,  82, 130],
#          [ 29,  82, 126],
#          [ 20,  64, 107]],
#
#         [[ 54, 107, 160],
#          [ 56, 105, 149],
#          [ 45,  89, 132],
#          ...,
#          [ 24,  77, 124],
#          [ 34,  84, 129],
#          [ 21,  67, 110]]],
#
#
#        [[[235, 235, 235],
#          [231, 231, 231],
#          [232, 232, 232],
#          ...,
#          [233, 233, 233],
#          [233, 233, 233],
#          [232, 232, 232]],
#
#         [[238, 238, 238],
#          [235, 235, 235],
#          [235, 235, 235],
#          ...,
#          [236, 236, 236],
#          [236, 236, 236],
#          [235, 235, 235]],
#
#         [[237, 237, 237],
#          [234, 234, 234],
#          [234, 234, 234],
#          ...,
#          [235, 235, 235],
#          [235, 235, 235],
#          [234, 234, 234]],
#
#         ...,
#
#         [[ 87,  99,  89],
#          [ 43,  51,  37],
#          [ 19,  23,  11],
#          ...,
#          [169, 184, 179],
#          [182, 197, 193],
#          [188, 202, 201]],
#
#         [[ 82,  96,  82],
#          [ 46,  57,  36],
#          [ 36,  44,  22],
#          ...,
#          [174, 189, 183],
#          [185, 200, 196],
#          [187, 202, 200]],
#
#         [[ 85, 101,  83],
#          [ 62,  75,  48],
#          [ 58,  67,  38],
#          ...,
#          [168, 183, 178],
#          [180, 195, 191],
#          [186, 200, 199]]],
#
#
#        [[[158, 190, 222],
#          [158, 187, 218],
#          [139, 166, 194],
#          ...,
#          [228, 231, 234],
#          [237, 239, 243],
#          [238, 241, 246]],
#
#         [[170, 200, 229],
#          [172, 199, 226],
#          [151, 176, 201],
#          ...,
#          [232, 232, 236],
#          [246, 246, 250],
#          [246, 247, 251]],
#
#         [[174, 201, 225],
#          [176, 200, 222],
#          [157, 179, 199],
#          ...,
#          [230, 229, 232],
#          [250, 249, 251],
#          [245, 244, 247]],
#
#         ...,
#
#         [[ 31,  40,  45],
#          [ 30,  39,  44],
#          [ 26,  35,  40],
#          ...,
#          [ 37,  40,  46],
#          [  9,  13,  14],
#          [  4,   7,   5]],
#
#         [[ 23,  34,  39],
#          [ 27,  38,  43],
#          [ 25,  36,  41],
#          ...,
#          [ 19,  20,  24],
#          [  4,   6,   3],
#          [  5,   7,   3]],
#
#         [[ 28,  41,  47],
#          [ 30,  43,  50],
#          [ 32,  45,  52],
#          ...,
#          [  5,   6,   8],
#          [  4,   5,   3],
#          [  7,   8,   7]]],
#
#
#        ...,
#
#
#        [[[ 20,  15,  12],
#          [ 19,  14,  11],
#          [ 15,  14,  11],
#          ...,
#          [ 10,   9,   7],
#          [ 12,  11,   9],
#          [ 13,  12,  10]],
#
#         [[ 21,  16,  13],
#          [ 20,  16,  13],
#          [ 18,  17,  12],
#          ...,
#          [ 10,   9,   7],
#          [ 10,   9,   7],
#          [ 12,  11,   9]],
#
#         [[ 21,  16,  13],
#          [ 21,  17,  12],
#          [ 20,  18,  11],
#          ...,
#          [ 12,  11,   9],
#          [ 12,  11,   9],
#          [ 13,  12,  10]],
#
#         ...,
#
#         [[ 33,  25,  13],
#          [ 34,  26,  15],
#          [ 34,  26,  15],
#          ...,
#          [ 28,  25,  52],
#          [ 29,  25,  58],
#          [ 23,  20,  42]],
#
#         [[ 33,  25,  14],
#          [ 34,  26,  15],
#          [ 34,  26,  15],
#          ...,
#          [ 27,  24,  52],
#          [ 27,  24,  56],
#          [ 25,  22,  47]],
#
#         [[ 31,  23,  12],
#          [ 32,  24,  13],
#          [ 33,  25,  14],
#          ...,
#          [ 24,  23,  50],
#          [ 26,  23,  53],
#          [ 25,  20,  47]]],
#
#
#        [[[ 25,  40,  12],
#          [ 15,  36,   3],
#          [ 23,  41,  18],
#          ...,
#          [ 61,  82,  78],
#          [ 92, 113, 112],
#          [ 75,  89,  92]],
#
#         [[ 12,  25,   6],
#          [ 20,  37,   7],
#          [ 24,  36,  15],
#          ...,
#          [115, 134, 138],
#          [149, 168, 177],
#          [104, 117, 131]],
#
#         [[ 12,  25,  11],
#          [ 15,  29,   6],
#          [ 34,  40,  24],
#          ...,
#          [154, 172, 182],
#          [157, 175, 192],
#          [116, 129, 151]],
#
#         ...,
#
#         [[100, 129,  81],
#          [103, 132,  84],
#          [104, 134,  86],
#          ...,
#          [ 97, 128,  84],
#          [ 98, 126,  84],
#          [ 91, 121,  79]],
#
#         [[103, 132,  83],
#          [104, 131,  83],
#          [107, 135,  87],
#          ...,
#          [101, 132,  87],
#          [ 99, 127,  84],
#          [ 92, 121,  79]],
#
#         [[ 95, 126,  78],
#          [ 95, 123,  76],
#          [101, 128,  81],
#          ...,
#          [ 93, 124,  80],
#          [ 95, 123,  81],
#          [ 92, 120,  80]]],
#
#
#        [[[ 73,  78,  75],
#          [ 98, 103, 113],
#          [ 99, 106, 114],
#          ...,
#          [135, 150, 152],
#          [135, 149, 154],
#          [203, 215, 223]],
#
#         [[ 69,  73,  70],
#          [ 84,  89,  97],
#          [ 68,  75,  81],
#          ...,
#          [ 85,  95,  89],
#          [ 71,  82,  80],
#          [120, 133, 135]],
#
#         [[ 69,  73,  70],
#          [ 90,  95, 100],
#          [ 62,  71,  74],
#          ...,
#          [ 74,  81,  70],
#          [ 53,  62,  54],
#          [ 62,  74,  69]],
#
#         ...,
#
#         [[123, 128,  96],
#          [132, 132, 102],
#          [129, 128, 100],
#          ...,
#          [108, 107,  88],
#          [ 62,  60,  55],
#          [ 27,  27,  28]],
#
#         [[115, 121,  91],
#          [123, 124,  95],
#          [129, 126,  99],
#          ...,
#          [115, 116,  94],
#          [ 66,  65,  59],
#          [ 27,  27,  27]],
#
#         [[116, 120,  90],
#          [121, 122,  94],
#          [129, 128, 101],
#          ...,
#          [116, 115,  94],
#          [ 68,  65,  58],
#          [ 27,  26,  26]]]], dtype=uint8)

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %%
x_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
y_train[0]
# Out:
# array([6], dtype=uint8)

# %%
y_train=y_train.reshape(-1,)
y_train[:5]
# Out:
# array([6, 9, 9, 4, 1], dtype=uint8)

# %%
y_test=y_test.reshape(-1,)
y_test[:5]
# Out:
# array([3, 8, 8, 0, 6], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,1))
plt.imshow(x_train[0])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,1))
plt.imshow(x_test[1])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,1))
plt.imshow(x_train[5])

# %%
y_train[9999]
# Out:
# 5

# %%
y_test[9999]
# Out:
# 7

# %%
classes=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
def plot_sample(x,y,index):
    plt.figure(figsize=(10,1))
    plt.imshow(x[index])
    plt.xlabel(classes[y[index]])

# %%
plt.figure(figsize=(10,1))
plt.imshow(x_train[10])

# %%
y_train[12]
# Out:
# 7

# %%
plot_sample(x_train,y_train,8)

# %%
y_train[8]
# Out:
# 8

# %%
plot_sample(x_train,y_train,9999)

# %%
y_train[9999]
# Out:
# 5

# %%
plot_sample(x_train,y_train,42345)

# %%
y_train[42345]
# Out:
# 2

# %% [markdown]
# # normalizing the training data

# %%
x_train=x_train/250.0
x_test=x_test/250.0

# %%
x_train[0]
# Out:
# array([[[0.236, 0.248, 0.252],
#         [0.172, 0.184, 0.18 ],
#         [0.2  , 0.192, 0.172],
#         ...,
#         [0.632, 0.528, 0.432],
#         [0.608, 0.5  , 0.408],
#         [0.592, 0.496, 0.412]],
#
#        [[0.064, 0.08 , 0.08 ],
#         [0.   , 0.   , 0.   ],
#         [0.072, 0.032, 0.   ],
#         ...,
#         [0.492, 0.352, 0.22 ],
#         [0.476, 0.332, 0.2  ],
#         [0.488, 0.348, 0.228]],
#
#        [[0.1  , 0.096, 0.084],
#         [0.064, 0.028, 0.   ],
#         [0.196, 0.108, 0.032],
#         ...,
#         [0.472, 0.336, 0.2  ],
#         [0.48 , 0.336, 0.2  ],
#         [0.436, 0.292, 0.168]],
#
#        ...,
#
#        [[0.832, 0.68 , 0.384],
#         [0.804, 0.612, 0.136],
#         [0.792, 0.644, 0.104],
#         ...,
#         [0.64 , 0.532, 0.28 ],
#         [0.224, 0.124, 0.028],
#         [0.212, 0.136, 0.08 ]],
#
#        [[0.72 , 0.556, 0.384],
#         [0.692, 0.492, 0.168],
#         [0.744, 0.576, 0.12 ],
#         ...,
#         [0.736, 0.592, 0.376],
#         [0.388, 0.248, 0.136],
#         [0.332, 0.212, 0.136]],
#
#        [[0.708, 0.576, 0.464],
#         [0.672, 0.516, 0.376],
#         [0.716, 0.568, 0.348],
#         ...,
#         [0.864, 0.736, 0.56 ],
#         [0.604, 0.472, 0.336],
#         [0.492, 0.368, 0.288]]])

# %%
ann=models.Sequential([
    layers.Flatten(input_shape=(32,32,3)),
    layers.Dense(30,activation='relu'),
    layers.Dense(15,activation='relu'),
    layers.Dense(10,activation='sigmoid')
])
ann.compile(optimizer='adam',
           loss='sparse_categorical_crossentropy',
           metrics='accuracy')
ann.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.1404 - accuracy: 0.1729
# Epoch 2/5
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.0758 - accuracy: 0.1843
# Epoch 3/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 2.0653 - accuracy: 0.1875
# Epoch 4/5
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.0615 - accuracy: 0.1883
# Epoch 5/5
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.0584 - accuracy: 0.1885

# %%
ann.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0460 - accuracy: 0.1877
# [2.0460023880004883, 0.18770000338554382]

# %%
from sklearn.metrics import classification_report
import numpy as np
y_pred=ann.predict(x_test)
y_pred_classes=[np.argmax(element) for element in y_pred]
print(classification_report(y_test,y_pred_classes))
# Out:
# 313/313 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.13      0.05      0.07      1000
#            1       0.00      0.00      0.00      1000
#            2       0.00      0.00      0.00      1000
#            3       0.14      0.28      0.18      1000
#            4       0.24      0.19      0.21      1000
#            5       0.16      0.22      0.18      1000
#            6       0.19      0.45      0.27      1000
#            7       0.00      0.00      0.00      1000
#            8       0.23      0.69      0.35      1000
#            9       0.00      0.00      0.00      1000
#
#     accuracy                           0.19     10000
#    macro avg       0.11      0.19      0.13     10000
# weighted avg       0.11      0.19      0.13     10000
# C:\Users\Naveen Kumar A\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Naveen Kumar A\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Naveen Kumar A\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cnn=models.Sequential([
    #features extraction
    layers.Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape=(32,32,3)),
    layers.MaxPooling2D(2,2),
    
    layers.Conv2D(filters=32,kernel_size=(2,2),activation='relu'),
    layers.MaxPooling2D(2,2),
    
    #classification
    layers.Flatten(),
    layers.Dense(200,activation='sigmoid'),
    layers.Dense(100,activation='sigmoid'),
    layers.Dense(10,activation='sigmoid')
])
cnn.compile(optimizer='adam',
           loss='sparse_categorical_crossentropy',
           metrics=['accuracy'])
cnn.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 28s 17ms/step - loss: 1.5525 - accuracy: 0.4323
# Epoch 2/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.1669 - accuracy: 0.5867
# Epoch 3/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9933 - accuracy: 0.6480
# Epoch 4/10
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8750 - accuracy: 0.6912
# Epoch 5/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.7737 - accuracy: 0.7291
# Epoch 6/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.6842 - accuracy: 0.7618
# Epoch 7/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.5977 - accuracy: 0.7924
# Epoch 8/10
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5132 - accuracy: 0.8228
# Epoch 9/10
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4355 - accuracy: 0.8514
# Epoch 10/10
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.3593 - accuracy: 0.8795

# %%
cnn.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.0479 - accuracy: 0.6855
# [1.0478501319885254, 0.6855000257492065]

# %%
y_pred=cnn.predict(x_test)
y_pred
# Out:
# 313/313 [==============================] - 2s 5ms/step
# array([[6.1662264e-02, 4.0383805e-02, 3.6329815e-01, ..., 7.1018869e-03,
#         2.9917094e-01, 4.1028918e-03],
#        [5.4641521e-01, 9.9802625e-01, 2.7663440e-02, ..., 4.6017776e-05,
#         9.9958271e-01, 1.9836815e-01],
#        [9.6787184e-01, 6.6119248e-01, 1.0559794e-01, ..., 1.2074802e-03,
#         9.8042911e-01, 1.5814173e-01],
#        ...,
#        [1.8407354e-01, 2.6643596e-04, 8.1953025e-01, ..., 8.3138674e-02,
#         5.1027715e-02, 2.1469155e-03],
#        [1.4761613e-01, 4.7036457e-01, 1.9028915e-02, ..., 2.8535867e-01,
#         1.9804074e-01, 4.4617560e-03],
#        [8.2241790e-03, 8.0600232e-03, 9.8586701e-02, ..., 9.9994898e-01,
#         5.0443483e-05, 8.0483323e-03]], dtype=float32)

# %%
y_classes=[np.argmax(element) for element in y_pred]
y_classes
# Out:
# [3,
#  8,
#  8,
#  0,
#  6,
#  6,
#  1,
#  6,
#  3,
#  1,
#  4,
#  9,
#  5,
#  7,
#  9,
#  6,
#  5,
#  7,
#  8,
#  6,
#  9,
#  2,
#  2,
#  9,
#  4,
#  2,
#  2,
#  0,
#  9,
#  6,
#  6,
#  2,
#  2,
#  3,
#  9,
#  3,
#  4,
#  1,
#  9,
#  5,
#  4,
#  6,
#  3,
#  6,
#  0,
#  9,
#  3,
#  3,
#  7,
#  6,
#  9,
#  8,
#  2,
#  3,
#  8,
#  8,
#  7,
#  8,
#  5,
#  3,
#  7,
#  5,
#  6,
#  3,
#  6,
#  2,
#  1,
#  2,
#  3,
#  7,
#  4,
#  6,
#  8,
#  8,
#  0,
#  2,
#  2,
#  5,
#  3,
#  8,
#  8,
#  0,
#  1,
#  7,
#  2,
#  7,
#  2,
#  7,
#  8,
#  9,
#  0,
#  6,
#  8,
#  6,
#  4,
#  6,
#  6,
#  0,
#  2,
#  3,
#  5,
#  5,
#  6,
#  3,
#  1,
#  1,
#  8,
#  6,
#  8,
#  7,
#  4,
#  0,
#  2,
#  2,
#  9,
#  4,
#  0,
#  4,
#  2,
#  5,
#  8,
#  3,
#  2,
#  2,
#  8,
#  0,
#  8,
#  3,
#  3,
#  2,
#  2,
#  1,
#  8,
#  9,
#  1,
#  2,
#  9,
#  7,
#  6,
#  8,
#  3,
#  5,
#  6,
#  5,
#  8,
#  7,
#  6,
#  6,
#  7,
#  3,
#  1,
#  1,
#  6,
#  5,
#  0,
#  3,
#  2,
#  9,
#  3,
#  4,
#  2,
#  1,
#  6,
#  6,
#  0,
#  4,
#  8,
#  6,
#  7,
#  0,
#  3,
#  9,
#  8,
#  8,
#  9,
#  9,
#  3,
#  7,
#  3,
#  0,
#  0,
#  5,
#  2,
#  6,
#  5,
#  0,
#  6,
#  2,
#  3,
#  8,
#  6,
#  8,
#  0,
#  7,
#  7,
#  6,
#  8,
#  8,
#  7,
#  8,
#  3,
#  9,
#  8,
#  7,
#  1,
#  3,
#  0,
#  4,
#  7,
#  9,
#  5,
#  0,
#  3,
#  7,
#  8,
#  4,
#  5,
#  9,
#  0,
#  7,
#  7,
#  3,
#  9,
#  4,
#  4,
#  9,
#  3,
#  2,
#  3,
#  2,
#  3,
#  1,
#  3,
#  8,
#  8,
#  0,
#  4,
#  7,
#  3,
#  5,
#  1,
#  9,
#  0,
#  9,
#  0,
#  8,
#  1,
#  8,
#  2,
#  0,
#  5,
#  3,
#  9,
#  9,
#  6,
#  0,
#  3,
#  0,
#  8,
#  9,
#  8,
#  9,
#  0,
#  3,
#  0,
#  8,
#  5,
#  4,
#  7,
#  0,
#  2,
#  7,
#  6,
#  3,
#  8,
#  2,
#  0,
#  5,
#  7,
#  5,
#  9,
#  9,
#  6,
#  1,
#  0,
#  9,
#  1,
#  8,
#  7,
#  9,
#  1,
#  2,
#  6,
#  1,
#  3,
#  2,
#  6,
#  8,
#  0,
#  6,
#  6,
#  6,
#  5,
#  5,
#  6,
#  1,
#  8,
#  3,
#  1,
#  4,
#  8,
#  6,
#  8,
#  2,
#  3,
#  0,
#  7,
#  7,
#  5,
#  5,
#  3,
#  5,
#  2,
#  2,
#  7,
#  1,
#  7,
#  5,
#  4,
#  6,
#  1,
#  9,
#  3,
#  6,
#  6,
#  9,
#  3,
#  9,
#  2,
#  7,
#  4,
#  6,
#  2,
#  7,
#  8,
#  5,
#  7,
#  6,
#  8,
#  9,
#  9,
#  1,
#  8,
#  2,
#  2,
#  7,
#  5,
#  2,
#  8,
#  0,
#  9,
#  5,
#  8,
#  0,
#  9,
#  2,
#  1,
#  0,
#  4,
#  1,
#  2,
#  7,
#  9,
#  4,
#  2,
#  7,
#  8,
#  7,
#  2,
#  6,
#  6,
#  8,
#  0,
#  0,
#  2,
#  0,
#  7,
#  4,
#  3,
#  5,
#  1,
#  2,
#  6,
#  6,
#  3,
#  6,
#  2,
#  5,
#  0,
#  1,
#  9,
#  8,
#  7,
#  8,
#  8,
#  6,
#  0,
#  1,
#  8,
#  2,
#  7,
#  8,
#  5,
#  6,
#  1,
#  9,
#  3,
#  4,
#  3,
#  7,
#  6,
#  7,
#  8,
#  0,
#  2,
#  9,
#  6,
#  3,
#  6,
#  6,
#  4,
#  5,
#  3,
#  5,
#  9,
#  7,
#  3,
#  6,
#  5,
#  1,
#  1,
#  2,
#  9,
#  9,
#  5,
#  2,
#  5,
#  0,
#  2,
#  2,
#  1,
#  9,
#  5,
#  3,
#  9,
#  4,
#  2,
#  4,
#  3,
#  9,
#  5,
#  6,
#  1,
#  4,
#  4,
#  4,
#  4,
#  3,
#  5,
#  1,
#  3,
#  2,
#  8,
#  0,
#  5,
#  7,
#  6,
#  0,
#  6,
#  6,
#  8,
#  6,
#  8,
#  7,
#  5,
#  9,
#  9,
#  9,
#  4,
#  0,
#  1,
#  7,
#  8,
#  1,
#  0,
#  8,
#  0,
#  2,
#  2,
#  0,
#  6,
#  6,
#  3,
#  2,
#  9,
#  4,
#  7,
#  9,
#  3,
#  4,
#  5,
#  6,
#  6,
#  1,
#  5,
#  3,
#  8,
#  9,
#  3,
#  8,
#  5,
#  7,
#  0,
#  7,
#  0,
#  6,
#  4,
#  0,
#  8,
#  6,
#  9,
#  8,
#  1,
#  5,
#  6,
#  6,
#  6,
#  2,
#  8,
#  0,
#  1,
#  5,
#  6,
#  7,
#  5,
#  9,
#  1,
#  6,
#  2,
#  5,
#  5,
#  3,
#  8,
#  3,
#  9,
#  4,
#  6,
#  3,
#  3,
#  2,
#  0,
#  7,
#  6,
#  2,
#  2,
#  5,
#  9,
#  7,
#  9,
#  2,
#  6,
#  7,
#  1,
#  4,
#  6,
#  6,
#  8,
#  8,
#  7,
#  3,
#  4,
#  0,
#  8,
#  2,
#  0,
#  1,
#  3,
#  4,
#  8,
#  9,
#  6,
#  9,
#  2,
#  6,
#  1,
#  0,
#  7,
#  3,
#  4,
#  3,
#  8,
#  5,
#  0,
#  2,
#  1,
#  6,
#  3,
#  4,
#  3,
#  9,
#  6,
#  9,
#  8,
#  8,
#  5,
#  8,
#  6,
#  6,
#  4,
#  1,
#  7,
#  1,
#  1,
#  2,
#  7,
#  9,
#  9,
#  4,
#  7,
#  1,
#  0,
#  3,
#  6,
#  3,
#  7,
#  6,
#  8,
#  3,
#  0,
#  5,
#  5,
#  6,
#  5,
#  7,
#  9,
#  9,
#  3,
#  3,
#  4,
#  5,
#  3,
#  9,
#  5,
#  6,
#  9,
#  2,
#  1,
#  1,
#  4,
#  1,
#  9,
#  4,
#  7,
#  2,
#  3,
#  0,
#  9,
#  0,
#  9,
#  5,
#  6,
#  5,
#  4,
#  3,
#  2,
#  8,
#  4,
#  9,
#  5,
#  3,
#  0,
#  6,
#  0,
#  0,
#  7,
#  2,
#  0,
#  5,
#  6,
#  6,
#  2,
#  2,
#  2,
#  7,
#  8,
#  3,
#  8,
#  2,
#  7,
#  5,
#  7,
#  2,
#  6,
#  2,
#  7,
#  4,
#  2,
#  3,
#  8,
#  8,
#  5,
#  0,
#  8,
#  7,
#  3,
#  3,
#  3,
#  2,
#  7,
#  9,
#  7,
#  8,
#  8,
#  1,
#  8,
#  8,
#  1,
#  5,
#  6,
#  5,
#  5,
#  0,
#  7,
#  9,
#  1,
#  2,
#  1,
#  2,
#  1,
#  5,
#  5,
#  7,
#  0,
#  7,
#  6,
#  7,
#  6,
#  6,
#  2,
#  3,
#  9,
#  0,
#  9,
#  1,
#  2,
#  4,
#  6,
#  8,
#  2,
#  1,
#  3,
#  6,
#  4,
#  0,
#  1,
#  2,
#  4,
#  9,
#  5,
#  2,
#  6,
#  9,
#  6,
#  3,
#  2,
#  2,
#  2,
#  6,
#  0,
#  6,
#  9,
#  1,
#  7,
#  6,
#  7,
#  0,
#  6,
#  9,
#  6,
#  8,
#  3,
#  0,
#  5,
#  7,
#  7,
#  7,
#  1,
#  3,
#  2,
#  4,
#  7,
#  1,
#  2,
#  7,
#  4,
#  4,
#  8,
#  6,
#  7,
#  3,
#  5,
#  3,
#  7,
#  5,
#  0,
#  8,
#  9,
#  3,
#  8,
#  0,
#  3,
#  7,
#  0,
#  8,
#  7,
#  4,
#  7,
#  6,
#  5,
#  3,
#  0,
#  6,
#  2,
#  5,
#  2,
#  4,
#  9,
#  2,
#  9,
#  2,
#  7,
#  0,
#  7,
#  2,
#  2,
#  3,
#  6,
#  0,
#  2,
#  4,
#  5,
#  9,
#  0,
#  1,
#  0,
#  7,
#  7,
#  0,
#  7,
#  8,
#  2,
#  6,
#  6,
#  3,
#  0,
#  1,
#  3,
#  7,
#  0,
#  1,
#  6,
#  1,
#  4,
#  2,
#  3,
#  8,
#  4,
#  3,
#  4,
#  2,
#  8,
#  3,
#  6,
#  0,
#  9,
#  0,
#  9,
#  1,
#  8,
#  4,
#  4,
#  6,
#  7,
#  3,
#  1,
#  1,
#  3,
#  7,
#  5,
#  5,
#  2,
#  6,
#  6,
#  5,
#  8,
#  7,
#  1,
#  6,
#  8,
#  8,
#  5,
#  3,
#  4,
#  4,
#  8,
#  1,
#  3,
#  8,
#  8,
#  0,
#  6,
#  9,
#  9,
#  6,
#  5,
#  5,
#  6,
#  6,
#  0,
#  8,
#  4,
#  2,
#  3,
#  3,
#  7,
#  2,
#  3,
#  5,
#  1,
#  8,
#  1,
#  9,
#  5,
#  4,
#  0,
#  3,
#  0,
#  0,
#  4,
#  8,
#  2,
#  9,
#  6,
#  0,
#  4,
#  7,
#  0,
#  6,
#  4,
#  8,
#  3,
#  1,
#  1,
#  6,
#  5,
#  6,
#  6,
#  0,
#  1,
#  9,
#  9,
#  4,
#  5,
#  1,
#  2,
#  0,
#  6,
#  8,
#  1,
#  9,
#  6,
#  9,
#  5,
#  4,
#  7,
#  8,
#  3,
#  1,
#  2,
#  2,
#  1,
#  3,
#  8,
#  5,
#  6,
#  2,
#  0,
#  1,
#  3,
#  8,
#  ...]

# %%
plot_sample(x_test,y_test,3)

# %%
classes[y_classes[3]]
# Out:
# 'airplane'

# %%
from sklearn.metrics import classification_report
import numpy as np
y_pred=cnn.predict(x_test)
y_pred_classes=[np.argmax(element) for element in y_pred]
print(classification_report(y_test,y_pred_classes))
# Out:
# 313/313 [==============================] - 2s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.67      0.76      0.71      1000
#            1       0.82      0.79      0.81      1000
#            2       0.58      0.60      0.59      1000
#            3       0.47      0.54      0.50      1000
#            4       0.66      0.56      0.61      1000
#            5       0.59      0.58      0.58      1000
#            6       0.69      0.81      0.74      1000
#            7       0.80      0.73      0.77      1000
#            8       0.82      0.79      0.81      1000
#            9       0.83      0.69      0.75      1000
#
#     accuracy                           0.69     10000
#    macro avg       0.69      0.69      0.69     10000
# weighted avg       0.69      0.69      0.69     10000
